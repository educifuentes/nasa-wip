# %% [markdown]
# # Playground

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
ocurrences_df = pd.read_csv("../data/processed/occurrences.csv")
events_df = pd.read_csv("../data/processed/events.csv")

# convert to datetime
ocurrences_df['date'] = pd.to_datetime(ocurrences_df['date'])
events_df['date'] = pd.to_datetime(events_df['date'])

# %%
events_df.head(1)
# Out:
#      event_id                        title description  \
# 0  EONET_6470  Lewotobi Volcano, Indonesia         NaN
#
#                                                 link     categories  \
# 0  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...  ['Volcanoes']
#
#                sources  closed  status category_titles date  longitude  \
# 0  ['EO', 'SIVolcano']     NaN     NaN             NaN  NaT        NaN
#
#    latitude continent country
# 0       NaN       NaN     NaN

# %%
print(f"Total events: {len(events_df)}")

agg_df = events_df.groupby(events_df['date']).agg(count=('date', 'size')).reset_index()

# Ensure date is in datetime format
agg_df['date'] = pd.to_datetime(agg_df['date'])

agg_df
# Out:
# Total events: 5689
#                           date  count
# 0    2024-01-04 00:00:00+00:00      4
# 1    2024-01-11 00:00:00+00:00      3
# 2    2024-01-18 00:00:00+00:00      1
# 3    2024-02-02 00:00:00+00:00      2
# 4    2024-02-08 00:00:00+00:00      2
# ...                        ...    ...
# 2051 2025-11-17 16:54:00+00:00      1
# 2052 2025-11-18 00:00:00+00:00      1
# 2053 2025-11-18 00:56:00+00:00      1
# 2054 2025-11-18 17:59:00+00:00      1
# 2055 2025-11-20 09:18:00+00:00      1
#
# [2056 rows x 2 columns]

# %%
agg_df = events_df.groupby(events_df['date']).agg(count=('date', 'size')).reset_index()

agg_df.tail()
# Out:
#                           date  count
# 2051 2025-11-17 16:54:00+00:00      1
# 2052 2025-11-18 00:00:00+00:00      1
# 2053 2025-11-18 00:56:00+00:00      1
# 2054 2025-11-18 17:59:00+00:00      1
# 2055 2025-11-20 09:18:00+00:00      1

# %%
ocurrences_df.head(2)
# Out:
#       event_id                                  event_title  \
# 0  EONET_15876  RX Rains 5318 Prescribed Fire, Rains, Texas
# 1  EONET_15877              PACK Wildfire, Mono, California
#
#                  event_description  \
# 0                              NaN
# 1  6 Miles S from CROWLEY LAKE, CA
#
#                                           event_link category_ids  \
# 0  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...    wildfires
# 1  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...    wildfires
#
#   category_titles  occurrence_date occurrence_type   longitude   latitude  \
# 0       Wildfires              NaN           Point  -95.682310  32.738759
# 1       Wildfires              NaN           Point -118.794566  37.555334
#
#    month  day      region        country      continent  \
# 0     11   14       Texas  United States  North America
# 1     11   13  California  United States  North America
#
#                        date
# 0 2025-11-14 08:07:00+00:00
# 1 2025-11-13 15:00:00+00:00

# %%
ocurrences_df["category_titles"].value_counts()
# Out:
# category_titles
# Wildfires           11165
# Sea and Lake Ice      936
# Severe Storms          86
# Volcanoes              40
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Load the processed data
data_path = Path('../data/processed/events_2025.csv')

if not data_path.exists():
    print(f"Warning: {data_path} does not exist. Please run data_pipeline.py first.")
else:
    # Load the CSV file
    df = pd.read_csv(data_path)
    
    # Convert occurrence_date to datetime
    df['occurrence_date'] = pd.to_datetime(df['occurrence_date'], errors='coerce')
    
    # Extract year, month, day if not already present
    if 'year' not in df.columns:
        df['year'] = df['occurrence_date'].dt.year
    if 'month' not in df.columns:
        df['month'] = df['occurrence_date'].dt.month
    if 'day' not in df.columns:
        df['day'] = df['occurrence_date'].dt.day
    
    print("Data loaded successfully!")
    print(f"Total records: {len(df)}")
    print(f"Date range: {df['occurrence_date'].min()} to {df['occurrence_date'].max()}")
# Out:
# Warning: ../data/processed/events_2025.csv does not exist. Please run data_pipeline.py first.

# %%
available_continents = sorted([c for c in ocurrences_df['continent'].dropna().unique()])
available_continents
# Out:
# ['Africa',
#  'Antarctica',
#  'Asia',
#  'Europe',
#  'North America',
#  'Oceania',
#  'South America']

# %%
ocurrences_df['continent'].value_counts()
# Out:
# continent
# North America    4050
# Africa           3172
# South America    1782
# Oceania          1408
# Asia              971
# Antarctica        792
# Europe             52
# Name: count, dtype: int64

# %%
events_df.sort_values(by='date', ascending=False).head(4)
# Out:
#        event_id                                              title  \
# 49  EONET_15984    RX Coleman 5431 Prescribed Fire, Coleman, Texas
# 50  EONET_15987  FY25 WEST CASTLE ROCK RX Prescribed Fire, Malh...
# 51  EONET_15986         Concord Fire Wildfire, Montgomery, Alabama
# 52  EONET_15898                              Tropical Cyclone Fina
#
#                       description  \
# 49                            NaN
# 50                            NaN
# 51  6 Miles NW from Talladega, AL
# 52                            NaN
#
#                                                  link         categories  \
# 49  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...      ['Wildfires']
# 50  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...      ['Wildfires']
# 51  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...      ['Wildfires']
# 52  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...  ['Severe Storms']
#
#       sources  closed  status category_titles                      date  \
# 49  ['IRWIN']     NaN     NaN       Wildfires 2025-11-20 09:18:00+00:00
# 50  ['IRWIN']     NaN     NaN       Wildfires 2025-11-18 17:59:00+00:00
# 51  ['IRWIN']     NaN     NaN       Wildfires 2025-11-18 00:56:00+00:00
# 52   ['JTWC']     NaN     NaN   Severe Storms 2025-11-18 00:00:00+00:00
#
#      longitude   latitude      continent        country
# 49  -99.390833  31.950833  North America  United States
# 50 -118.183545  44.027127  North America  United States
# 51  -86.177222  32.436944  North America  United States
# 52  130.500000 -10.200000        Oceania      Australia

# %%
ocurrences_df_agg_daily = ocurrences_df.groupby(ocurrences_df['date']).agg(count=('date', 'size')).reset_index()
ocurrences_df_agg_daily['date'] = pd.to_datetime(ocurrences_df_agg_daily['date'])

max_date = ocurrences_df_agg_daily["date"].max()
print(f"Max date: {max_date}")

ocurrences_df[ocurrences_df["date"] == max_date]
# Out:
# Max date: 2025-11-21 06:00:00+00:00
#          event_id            event_title event_description  \
# 6154  EONET_15898  Tropical Cyclone Fina               NaN
#
#                                              event_link  category_ids  \
# 6154  https://eonet.gsfc.nasa.gov/api/v3/events/EONE...  severeStorms
#
#      category_titles  occurrence_date occurrence_type  longitude  latitude  \
# 6154   Severe Storms              NaN           Point      132.4     -10.7
#
#       month  day              region    country continent  \
# 6154     11   21  Northern Territory  Australia   Oceania
#
#                           date
# 6154 2025-11-21 06:00:00+00:00
